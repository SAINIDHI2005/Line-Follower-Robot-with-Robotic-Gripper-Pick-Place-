# %%
# !pip install torch-geometric
# Out:
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.13.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.15.0)

# %%
#%load_ext autoreload
#%autoreload 2
import os
import time
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn

from ag_utils import Corpus
from ag_utils import parse_ag_file
from ag_utils import parse_node_properties

from synthetic_data import gene_dataset

from models import NN, GCN, GAT, GCN_EW
from model_utils import train, predict_prob, evaluate_performance

# %%
# parse attack graph file generated by MulVAL tool
attack_graph_path = '../mulval_attack_graph/AttackGraph.dot'
nodes, edges, node_properties = parse_ag_file(attack_graph_path)
node_dict = parse_node_properties(nodes, node_properties)

# save node label into corpus object
corpus = Corpus(node_dict)
num_tokens = corpus.get_num_tokens()
node_features = corpus.get_node_features()
node_types = corpus.get_node_types()
vocab_size = len(corpus.dictionary)
print('vocab_size: ', vocab_size)
print('num_tokens: ', num_tokens)
print('node_features shape: ', node_features.shape)
# Out:
# vocab_size:  57
# num_tokens:  118
# node_features shape:  torch.Size([26, 57])

# %%
# statistics of the encoded attack graph
num_nodes = len(nodes)
print('num_nodes: ', num_nodes)

num_node_features = node_features.shape[1]
print('num_node_features: ', num_node_features)

num_edges = len(edges)
print('num_edges: ', num_edges)

action_nodes = corpus.get_action_nodes()
action_node_idx = list(action_nodes.keys())
num_action_nodes = len(action_node_idx)
print('action_node_idx: ', action_node_idx)
print('num_action_nodes: ', num_action_nodes)

# var 'action_mask' is for representing the attack scenarios in attack graph (i.e., the privilege nodes)
action_mask = action_node_idx
# Out:
# num_nodes:  26
# num_node_features:  57
# num_edges:  26
# action_node_idx:  [0, 2, 4, 7, 9, 12, 14]
# num_action_nodes:  7

# %%
# adj matrix and edge index
adj_matrix = torch.zeros(len(nodes), len(nodes))

for edge in edges:
    source_node, target_node = edge
    source_index = nodes.index(source_node)
    target_index = nodes.index(target_node)
    adj_matrix[source_index][target_index] = 1

edge_index = adj_matrix.nonzero().t().contiguous()

assert edge_index.shape[0]==2

degrees = torch.zeros(num_nodes)

for src, dst in edge_index.t():
    degrees[src] += 1
    degrees[dst] += 1

print(degrees)
# Out:
# tensor([1., 2., 2., 3., 3., 3., 1., 2., 4., 2., 3., 1., 3., 4., 2., 3., 1., 1.,
#         1., 1., 1., 1., 4., 1., 1., 1.])

# %%
# prepare Dataset 1
num_benign = 1500
num_malic = 500
rt_meas_dim = 78
sample_method = 'synthetic'

X, Y = gene_dataset(num_benign, num_malic, num_nodes, action_nodes, rt_meas_dim)
num_samples = X.shape[0]

# rescale the data with min-max scaler
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X.view(-1, rt_meas_dim))
X = torch.from_numpy(X).float().view(num_samples, num_nodes, rt_meas_dim)

# associate node features in attack graph with real-time measurements
node_feat_ts = torch.stack([node_features for _ in range(len(X))], dim=0)
X = torch.cat((node_feat_ts, X), dim=2)

# split the data into training, validation and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=42, stratify=Y_train)
print(X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape)
# Out:
# torch.Size([3000, 26, 135]) torch.Size([3000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7])

# %%
original_num_edges = edge_index.shape[1]

print("Original Edges:", original_num_edges)
# Out:
# Original Edges: 26

# %%
original_num_nodes = num_nodes

print("Original Nodes:", original_num_nodes)
# Out:
# Original Nodes: 26

# %%
original_sparsity = 1 - (original_num_edges / (original_num_nodes * (original_num_nodes - 1)))

print("Original Sparsity:", original_sparsity)
# Out:
# Original Sparsity: 0.96

# %%
threshold = 2
keep_nodes = (degrees >= threshold).nonzero().view(-1)

print(keep_nodes)
# Out:
# tensor([ 1,  2,  3,  4,  5,  7,  8,  9, 10, 12, 13, 14, 15, 22])

# %%
node_mapping = {old.item(): new for new, old in enumerate(keep_nodes)} # renumbering nodes

# %%
new_edges = []

for src, dst in edge_index.t():
    if src.item() in node_mapping and dst.item() in node_mapping:
        new_src = node_mapping[src.item()]
        new_dst = node_mapping[dst.item()]
        new_edges.append([new_src, new_dst])

edge_index_pruned = torch.tensor(new_edges).t().contiguous()

# %%
node_features_pruned = node_features[keep_nodes]

# %%
X = torch.cat((node_feat_ts, X), dim=2)
X = X[:, keep_nodes, :]

# %%
num_nodes = len(keep_nodes)

# %%
pruned_num_nodes = num_nodes

print("Pruned Nodes:", pruned_num_nodes)
# Out:
# Pruned Nodes: 14

# %%
node_reduction = ((original_num_nodes - pruned_num_nodes) / original_num_nodes) * 100

print("Node Reduction %:", node_reduction)
# Out:
# Node Reduction %: 46.15384615384615

# %%
edge_index = edge_index_pruned

# %%
pruned_num_edges = edge_index.shape[1]

print("Pruned Edges:", pruned_num_edges)
# Out:
# Pruned Edges: 14

# %%
edge_reduction = ((original_num_edges - pruned_num_edges) / original_num_edges) * 100

print("Edge Reduction %:", edge_reduction)
# Out:
# Edge Reduction %: 46.15384615384615

# %%
pruned_sparsity = 1 - (pruned_num_edges / (pruned_num_nodes * (pruned_num_nodes - 1)))

print("Pruned Sparsity:", pruned_sparsity)
# Out:
# Pruned Sparsity: 0.9230769230769231

# %%
# load Dataset 1 used in the paper
data_path = '../datasets/synt/'
X_train = torch.load(data_path+'X_train-{}.pth'.format(sample_method))
X_val   = torch.load(data_path+'X_val-{}.pth'.format(sample_method))
X_test  = torch.load(data_path+'X_test-{}.pth'.format(sample_method))
Y_train = torch.load(data_path+'Y_train-{}.pth'.format(sample_method))
Y_val   = torch.load(data_path+'Y_val-{}.pth'.format(sample_method))
Y_test  = torch.load(data_path+'Y_test-{}.pth'.format(sample_method))
print(X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape)
# Out:
# torch.Size([3000, 26, 135]) torch.Size([3000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7]) torch.Size([1000, 26, 135]) torch.Size([1000, 7])

# %%
# hyperparameters for training
in_dim = X_train.shape[-1]
hidden_dim = 10
out_dim = 1
lr = 0.001
device = 'cpu'
# model initialization
models = {}
model_NN = NN(rt_meas_dim, hidden_dim, out_dim)
model_GCN = GCN(in_dim, hidden_dim, out_dim)
model_GCN_EW = GCN_EW(in_dim, hidden_dim, out_dim, edge_index)
model_GAT = GAT(hidden_channels=hidden_dim, heads=4, in_dim=in_dim, out_dim=out_dim)

models['NN'] = model_NN
models['GCN'] = model_GCN
models['GCN-EW'] = model_GCN_EW
models['GAT'] = model_GAT



for name, model in models.items():

    model.name = name
    model.action_mask = action_mask
    num_epochs = 10 # early stop when overfitting observed

    print(f'{model.name} start training...')
    time_start = time.time()
    print('model: ', model)
    train(model, lr, num_epochs, X_train, Y_train, X_val, Y_val, edge_index, rt_meas_dim, device)
    time_end = time.time()
    print('time cost: ', time_end - time_start)
    print(f'{model.name} Training Time: {time_end - time_start:.4f} seconds')
    print(f'{model.name} training finished!')

    print(f'{model.name} accuracy on training set: {model.stat["acc_train"][-1]}')
    print(f'{model.name} accuracy on validation set: {model.stat["acc_val"][-1]}')
# Out:
# NN start training...
# model:  NN(
#   (lin1): Linear(in_features=78, out_features=10, bias=True)
#   (lin2): Linear(in_features=10, out_features=10, bias=True)
#   (out_layer): Linear(in_features=10, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.8984, Traning Accuracy: 0.7799, Validation Loss: 0.9123, Validation Accuracy: 0.7783
# time cost:  2.076997995376587
# NN Training Time: 2.0770 seconds
# NN training finished!
# NN accuracy on training set: 0.7799047619047619
# NN accuracy on validation set: 0.7782857142857142
# GCN start training...
# model:  GCN(
#   (conv1): GCNConv(135, 10)
#   (conv2): GCNConv(10, 10)
#   (classifier): Linear(in_features=10, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.8601, Traning Accuracy: 0.8302, Validation Loss: 0.8815, Validation Accuracy: 0.8347
# time cost:  12.43635869026184
# GCN Training Time: 12.4364 seconds
# GCN training finished!
# GCN accuracy on training set: 0.8301904761904761
# GCN accuracy on validation set: 0.8347142857142857
# GCN-EW start training...
# model:  GCN_EW(
#   (conv1): GCNConv(135, 10)
#   (conv2): GCNConv(10, 10)
#   (classifier): Linear(in_features=10, out_features=1, bias=True)
# )
# Epoch: 010, Training Loss: 0.7287, Traning Accuracy: 0.8532, Validation Loss: 0.7487, Validation Accuracy: 0.8574
# time cost:  8.071026086807251
# GCN-EW Training Time: 8.0710 seconds
# GCN-EW training finished!
# GCN-EW accuracy on training set: 0.8531904761904762
# GCN-EW accuracy on validation set: 0.8574285714285714
# GAT start training...
# model:  GAT(
#   (conv1): GATConv(135, 10, heads=4)
#   (conv2): GATConv(40, 10, heads=4)
#   (classifier): Linear(in_features=40, out_features=1, bias=True)
# )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1644/222310459.py in <cell line: 0>()
#      28     time_start = time.time()
#      29     print('model: ', model)
# ---> 30     train(model, lr, num_epochs, X_train, Y_train, X_val, Y_val, edge_index, rt_meas_dim, device)
#      31     time_end = time.time()
#      32     print('time cost: ', time_end - time_start)
#
# /content/GNN-IDS/src/model_utils.py in train(model, lr, num_epochs, X_train, Y_train, X_val, Y_val, edge_index, rt_meas_dim, device)
#      47             optimizer.step()
#      48
# ---> 49         loss_train, acc_train = evaluate_loss_acc(model, X_train, Y_train, criterion, edge_index, device)
#      50         loss_val, acc_val     = evaluate_loss_acc(model, X_val, Y_val, criterion, edge_index, device=device)
#      51
#
# /content/GNN-IDS/src/model_utils.py in evaluate_loss_acc(model, X, y, criterion, edge_index, device)
#      74             true_pred = []
#      75             for i in range(len(X)):
# ---> 76                 output = model(X[i], edge_index)
#      77                 loss += criterion(output[mask], y[i])
#      78                 y_pred = torch.sigmoid(output[mask]) > 0.5
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /content/GNN-IDS/src/models.py in forward(self, x, edge_index)
#      64
#      65     def forward(self, x, edge_index):
# ---> 66         h = self.conv1(x, edge_index).relu()
#      67         h = self.conv2(h, edge_index).relu()
#      68
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1770         return result
#    1771
# -> 1772     def _wrapped_call_impl(self, *args, **kwargs):
#    1773         if self._compiled_call_impl is not None:
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
feature_dim = X_train.shape[2]

gcn_flops_before = original_num_edges * feature_dim
gcn_flops_after = pruned_num_edges * feature_dim

print("GCN FLOPs Before:", gcn_flops_before)
print("GCN FLOPs After:", gcn_flops_after)

# %%
heads = 4

gat_flops_before = original_num_edges * feature_dim * heads
gat_flops_after = pruned_num_edges * feature_dim * heads

print("GAT FLOPs Before:", gat_flops_before)
print("GAT FLOPs After:", gat_flops_after)

# %%
memory_before = edge_index.element_size() * edge_index.nelement()

memory_after = edge_index_pruned.element_size() * edge_index_pruned.nelement()

print("Memory Before:", memory_before, "bytes")
print("Memory After:", memory_after, "bytes")

# %%
# plot the roc curve
from sklearn.metrics import roc_curve, auc
fig, ax = plt.subplots(figsize=(5, 5))
for name, model in models.items():
    prob = predict_prob(model, X_test, edge_index)
    y_probs = prob.view(-1, 2)

    fpr, tpr, thresholds = roc_curve(Y_test.view(-1), y_probs[:, 1])
    roc_auc = auc(fpr, tpr)

    ax.plot(fpr, tpr, label='{} (AUC = {:.4f})'.format(model.name, roc_auc))
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_title('Receiver Operating Characteristic (ROC) Curve')
    ax.legend(loc="lower right")
ax.grid()
plt.show()

# %%
# performance evaluation
metrics = evaluate_performance(models, X_test, Y_test, edge_index, device)
df = pd.DataFrame(metrics)
print(df)

# %%
# plot the TP, FP, TN, FN
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs = axs.ravel()

bar_width = 0.5
labels = ['TN', 'FP', 'FN', 'TP']

for i, label in enumerate(labels):
    for j, name in enumerate(models):
        rects = axs[i].bar(j, metrics[j][label], width=bar_width, label=name)
    axs[i].set_xticks(np.arange(len(models)))
    axs[i].set_xticklabels(models.keys())
    for tick in axs[i].xaxis.get_major_ticks():
        tick.label1.set_fontsize(10)
    axs[i].set_title(label)

handles, labels = axs[0].get_legend_handles_labels()

plt.tight_layout()
plt.show()

# %%
# robustness evaluation
for i in range(Y_test.shape[0]):
    for j in range(len(action_mask)):
        if Y_test[i, j] == 1:
            for k in range(rt_meas_dim):
                if True:
                    X_test[i, action_mask[j],-rt_meas_dim+k] -= torch.normal(mean=0.0, std=0.05, size=(1,)).item()

metrics = evaluate_performance(models, X_test, Y_test, edge_index, device)
df = pd.DataFrame(metrics)
print(df)

# %%
from torch_geometric.data import Data
from torch_geometric.explain import GNNExplainer, Explainer

# individual case analysis
found = False
while not found:
    indi_case_id = torch.randint(0, X_test.shape[0], (1,)).item()
    y_true = Y_test[indi_case_id]
    if y_true.sum() != 0:
        found = True
        print('indi_case_id: ', indi_case_id)

indi_case_x = X_test[indi_case_id]
indi_case_x = indi_case_x.unsqueeze(0)

# %%
# Explainability visualization
model_to_explain = model_GCN_EW
model_to_explain.eval()
if model.name in ['GAT']:
    indi_case_x = indi_case_x.view(-1, in_dim)
prob_ts = torch.sigmoid(model_to_explain(indi_case_x, edge_index))[action_mask]
print('model prob_ts: \n', prob_ts)
print('y_true: ', y_true)

data = Data(x=X_test[indi_case_id], edge_index=edge_index)

explainer = Explainer(
    model=model_to_explain,
    algorithm=GNNExplainer(epochs=200),
    explanation_type='model',
    node_mask_type='attributes',
    edge_mask_type='object',
    model_config=dict(
        mode='binary_classification',
        task_level='node',
        return_type='raw',
    ),
)

compromised_node = action_node_idx[np.where(y_true==1)[0].item()]
explanation = explainer(data.x, data.edge_index, index=compromised_node)

explanation.visualize_feature_importance(top_k=10)
explanation.visualize_graph()

# %%
results = {
    "Metric": [
        "Nodes",
        "Edges",
        "Node Reduction %",
        "Edge Reduction %",
        "Sparsity",
        "GCN FLOPs",
        "GAT FLOPs"
    ],

    "Before": [
        original_num_nodes,
        original_num_edges,
        0,
        0,
        original_sparsity,
        gcn_flops_before,
        gat_flops_before
    ],

    "After": [
        pruned_num_nodes,
        pruned_num_edges,
        node_reduction,
        edge_reduction,
        pruned_sparsity,
        gcn_flops_after,
        gat_flops_after
    ]
}

metrics_df = pd.DataFrame(results)

print(metrics_df)
